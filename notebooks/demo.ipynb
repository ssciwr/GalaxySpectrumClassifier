# %% [markdown]
# # Demo of the GalaxySpectrumClassifier package

# %% [markdown]
# In the following we will demonstrate the GalaxySpectrumClassifier package. It is currently capable of doing impressive things:

# %%
import GalaxySpectrumClassifier

# %%
GalaxySpectrumClassifier.add_one(1)

# %% [markdown]
# There you go: `1+1=2`!
